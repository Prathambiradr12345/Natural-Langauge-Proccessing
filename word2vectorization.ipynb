# %% [markdown]
# <a href="https://colab.research.google.com/github/Prathambiradr12345/Natural-Langauge-Proccessing/blob/main/word2vectorization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#word embeddings=Convert word into vector
#type=frequency=bag of words,tf-idf,glove,prediction=word2vec

# %%
#word2Vec=convert word into vector,developed by google
#advantages=semantiic meaning ko capture kar pata hai eg.happy,joy ,convert word into low vector[100-300],dense vector(most of numbers is non-zero[1,1,1,1,1]),reduce the overfitting

# %%
#type of word2vec
#1.Cbow= it is used for small datasets    2.skip-grams=it is used for large dataset
#word2vec improve quality=1.increse the training data.2.increase dimesion of vector when vector increses.

# %%
import numpy as np
import pandas as pd
# !pip install gensim

# %%
import gensim
import os

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess
story=[]
for filename in os.listdir('dr.txt'):
    f=open(os.path.join('dr.txt',filename))
    corpus=f.read()
    raw_sent=sent_tokenize(corpus)
    for sent in raw_sent:
      story.append(simple_preprocess(sent))
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-5-63c40f65cbac> in <cell line: 4>()
#       2 from gensim.utils import simple_preprocess
#       3 story=[]
# ----> 4 for filename in os.listdir('dr.txt'):
#       5     f=open(os.path.join('dr.txt',filename))
#       6     corpus=f.read()
#
# NotADirectoryError: [Errno 20] Not a directory: 'dr.txt'

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess
story=[]

# Open and read the file directly
with open('dr.txt', 'r') as f:
    corpus = f.read()

# Process the corpus
raw_sent = sent_tokenize(corpus)
for sent in raw_sent:
    story.append(simple_preprocess(sent))
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-6-575cf19ed2f1> in <cell line: 10>()
#       8
#       9 # Process the corpus
# ---> 10 raw_sent = sent_tokenize(corpus)
#      11 for sent in raw_sent:
#      12     story.append(simple_preprocess(sent))
#
# /usr/local/lib/python3.10/dist-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#     121
#
# /usr/local/lib/python3.10/dist-packages/nltk/tokenize/__init__.py in _get_punkt_tokenizer(language)
#     103     :type language: str
#     104     """
# --> 105     return PunktTokenizer(language)
#     106
#     107
#
# /usr/local/lib/python3.10/dist-packages/nltk/tokenize/punkt.py in __init__(self, lang)
# ...

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess
import nltk # Import nltk

# Download the 'punkt_tab' data package
nltk.download('punkt_tab') # Download the necessary data package

story=[]

# Open and read the file directly
with open('dr.txt', 'r') as f:
    corpus = f.read()

# Process the corpus
raw_sent = sent_tokenize(corpus)
for sent in raw_sent:
    story.append(simple_preprocess(sent))
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
story
# Out:
# [['game',
#   'of',
#   'thrones',
#   'book',
#   'one',
#   'of',
#   'song',
#   'of',
#   'ice',
#   'and',
#   'fire',
#   'by',
#   'george',
#   'martin',
#   'prologue',
#   'we',
#   'should',
#   'start',
#   'back',
#   'gared',
#   'urged',
#   'as',
#   'the',
#   'woods',
#   'began',
#   'to',
#   'grow',
#   'dark',
#   'around',
#   'them'],
#  ['the', 'wildlings', 'are', 'dead'],
#  ['do', 'the', 'dead', 'frighten', 'you'],
#  ['ser',
#   'waymar',
#   'royce',
#   'asked',
#   'with',
#   'just',
#   'the',
#   'hint',
#   'of',
#   'smile'],
#  ['gared', 'did', 'not', 'rise', 'to', 'the', 'bait'],
#  ['he',
#   'was',
#   'an',
#   'old',
#   'man',
#   'past',
#   'fifty',
#   'and',
#   'he',
#   'had',
#   'seen',
#   'the',
#   'lordlings',
#   'come',
#   'and',
#   'go'],
#  ['dead', 'is', 'dead', 'he', 'said'],
#  ['we', 'have', 'no', 'business', 'with', 'the', 'dead'],
#  ['are', 'they', 'dead'],
#  ['royce', 'asked', 'softly'],
# ...

# %%
model=gensim.models.Word2Vec(window=10,min_count=2)

# %%
model

# %%
model.build_vocab(story)

# %%
model=gensim.models.Word2Vec(window=10,min_count=2)
# Build the vocabulary from your training data 'story'
model.build_vocab(story)
# Now you can train the model
model.train(story,total_examples=model.corpus_count,epochs=model.epochs)
# Out:
# (1059227, 1423500)

# %%
model.wv.most_similar('man')
# Out:
# [('one', 0.9368057250976562),
#  ('day', 0.9333940744400024),
#  ('toy', 0.9332718849182129),
#  ('boy', 0.9324226975440979),
#  ('particular', 0.92971271276474),
#  ('place', 0.9239071607589722),
#  ('years', 0.9234983325004578),
#  ('mood', 0.9233077764511108),
#  ('answers', 0.9230505228042603),
#  ('born', 0.9216017723083496)]

# %%
model.wv.doesnt_match(['man','woman','prince'])
# Out:
# 'man'

# %%
model.wv.doesnt_match(['man','woman','prince'])
# Out:
# 'man'

# %%
model.wv['man'].shape
# Out:
# (100,)

# %%
model.wv.similarity('man','woman')
# Out:
# 0.88115734

# %%
model.wv.similarity('man','prince')
# Out:
# 0.829875

# %%
model.wv.get_normed_vectors()
# Out:
# array([[-0.04166728,  0.06432994, -0.00277177, ..., -0.14013739,
#          0.0046341 ,  0.12232436],
#        [-0.0471337 ,  0.10939895, -0.02491742, ..., -0.20459649,
#          0.05554092,  0.04457093],
#        [-0.15339456,  0.03132918, -0.00433766, ..., -0.08913324,
#          0.03890958, -0.1390674 ],
#        ...,
#        [-0.08307648, -0.07087988,  0.03897029, ..., -0.12738052,
#          0.04526558, -0.08758008],
#        [-0.02915108,  0.06340492,  0.00134828, ..., -0.17940111,
#         -0.00666257, -0.00869496],
#        [-0.03184785,  0.13415271, -0.01545663, ..., -0.17278373,
#          0.01797149, -0.03686895]], dtype=float32)

# %%
y=model.wv.index_to_key

# %%
y
# Out:
# ['the',
#  'and',
#  'to',
#  'of',
#  'he',
#  'his',
#  'was',
#  'her',
#  'you',
#  'in',
#  'it',
#  'she',
#  'had',
#  'as',
#  'him',
#  'with',
#  'that',
#  'said',
#  'not',
#  'for',
#  'at',
#  'on',
#  'they',
#  'but',
#  'is',
#  'my',
#  'lord',
#  'no',
#  'from',
#  'them',
#  'have',
#  'would',
#  'were',
#  'be',
#  'all',
#  'your',
#  'when',
#  'ser',
#  'me',
#  'if',
#  'will',
#  'so',
#  'jon',
#  'could',
#  'what',
#  'one',
#  'ned',
#  'man',
#  'their',
#  'there',
#  'king',
#  'up',
#  'out',
#  'are',
#  'this',
#  'back',
#  'been',
#  'we',
#  'do',
#  'did',
#  'father',
#  'down',
#  'tyrion',
#  'like',
#  'men',
#  'by',
#  'hand',
#  'page',
#  'eyes',
#  'bran',
#  'than',
#  'now',
#  'only',
#  'or',
#  'told',
#  'see',
#  'catelyn',
#  'who',
#  'more',
#  'arya',
#  'off',
#  'here',
#  'even',
#  'an',
#  'face',
#  'boy',
#  'over',
#  'brother',
#  'into',
#  'know',
#  'sansa',
#  'old',
#  'dany',
#  'black',
#  'robb',
# ...

# %%
len(y)
# Out:
# 7432

# %%
from sklearn.decomposition import PCA #convert 100 dimesion to 3 dimesion
pca=PCA(n_components=3)
X=pca.fit_transform(model.wv.get_normed_vectors())
X[:5]
# Out:
# array([[-0.35648933,  0.20192921,  0.30892536],
#        [-0.4503009 ,  0.07225484,  0.23309669],
#        [ 0.4033394 ,  0.12214577, -0.0372763 ],
#        [-0.29411954,  0.09377074,  0.52449405],
#        [ 0.20113683,  0.3143944 , -0.38431796]], dtype=float32)

# %%
x.shape
# Out:
# (7432, 3)

# %%
import plotly.express as px

# Ensure 'color' has the same length as 'x', 'y', 'z'
# Here, we are using the first 10 colors for the first 10 points,
# and then repeating the colors for the remaining points.
colors = y[:10] * (len(X) // 10) + y[:len(X) % 10]

# Use the first three columns of X for the x, y, and z dimensions
fig = px.scatter_3d(x=X[:,0], y=X[:,1], z=X[:,2], color=colors)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
